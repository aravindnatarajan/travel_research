# %%
import explore

# %%
# City to research.
city = 'Samarkhand'

# Output file to write to.
output = 'destinations/samarkhand.txt'

# %%
explore.research(city, output)
# Out:
# Generating some queries to search for . . . Generated 8 queries.
# Searching for web links . . . 38 links found.
# Scraping data from web links . . . Done.
# Summarizing collected documents. . . Done.
# Building a RAG system and answering generated questions . . . Done.
# Putting it all together, and writing to output file . . . Done.
